# %% [markdown]
# ---
# # kiwi 라이브러리
# ---
#
# - colab 사용
# - 깃허브 주소: https://github.com/bab2min/kiwipiepy

# %%
pip install kiwipiepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.13.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 8.4 MB/s
# Collecting kiwipiepy-model~=0.13
#   Downloading kiwipiepy_model-0.13.0.tar.gz (30.0 MB)
#      |████████████████████████████████| 30.0 MB 1.2 MB/s
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Building wheels for collected packages: kiwipiepy-model
#   Building wheel for kiwipiepy-model (setup.py) ... done
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.13.0-py3-none-any.whl size=30103568 sha256=eb004baedb4eaa5d9bd1b2d9d1a816c6c35dd13cff0dd89aab4dfc1c23f1db3e
#   Stored in directory: /root/.cache/pip/wheels/ef/76/54/24f8a4f8de9818e0847b719cd7be1611f14eb1ce8d3dfe2460
# Successfully built kiwipiepy-model
# Installing collected packages: kiwipiepy-model, dataclasses, kiwipiepy
# Successfully installed dataclasses-0.6 kiwipiepy-0.13.1 kiwipiepy-model-0.13.0

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %% [markdown]
# ---
# ### 형태소 분석 결과
# ---

# %%
kiwi.tokenize('아니 무슨 장난하는것도 아니고 떡볶이가 차갑게 나와서 다시 달라했더니 전자렌지에 돌려서 주네요 기분 더러웠습니다^^ 차가운 떡볶이 혹은 전자렌지 떡볶이드시려면 여기 가세여')
# Out:
# [Token(form='아니', tag='IC', start=0, len=2),
#  Token(form='무슨', tag='MM', start=3, len=2),
#  Token(form='장난', tag='NNG', start=6, len=2),
#  Token(form='하', tag='XSV', start=8, len=1),
#  Token(form='는', tag='ETM', start=9, len=1),
#  Token(form='것', tag='NNB', start=10, len=1),
#  Token(form='도', tag='JX', start=11, len=1),
#  Token(form='아니', tag='VCN', start=13, len=2),
#  Token(form='고', tag='EC', start=15, len=1),
#  Token(form='떡볶이', tag='NNG', start=17, len=3),
#  Token(form='가', tag='JKS', start=20, len=1),
#  Token(form='차갑', tag='VA-I', start=22, len=2),
#  Token(form='게', tag='EC', start=24, len=1),
#  Token(form='나오', tag='VV', start=26, len=2),
#  Token(form='어서', tag='EC', start=27, len=2),
#  Token(form='다시', tag='MAG', start=30, len=2),
#  Token(form='달', tag='VV', start=33, len=1),
#  Token(form='라', tag='EC', start=34, len=1),
#  Token(form='하', tag='VV', start=35, len=1),
#  Token(form='었', tag='EP', start=35, len=1),
#  Token(form='더니', tag='EC', start=36, len=2),
#  Token(form='전자렌지', tag='NNG', start=39, len=4),
#  Token(form='에', tag='JKB', start=43, len=1),
#  Token(form='돌리', tag='VV', start=45, len=2),
#  Token(form='어서', tag='EC', start=46, len=2),
#  Token(form='주', tag='VX', start=49, len=1),
#  Token(form='네요', tag='EF', start=50, len=2),
#  Token(form='기분', tag='NNG', start=53, len=2),
#  Token(form='더럽', tag='VA-I', start=56, len=3),
#  Token(form='었', tag='EP', start=58, len=1),
#  Token(form='습니다', tag='EF', start=59, len=3),
#  Token(form='^^', tag='SW', start=62, len=2),
#  Token(form='차갑', tag='VA-I', start=65, len=3),
#  Token(form='은', tag='ETM', start=67, len=1),
#  Token(form='떡볶이', tag='NNG', start=69, len=3),
#  Token(form='혹은', tag='MAG', start=73, len=2),
#  Token(form='전자렌지', tag='NNG', start=76, len=4),
#  Token(form='떡볶이', tag='NNG', start=81, len=3),
#  Token(form='들', tag='VV', start=84, len=1),
#  Token(form='시', tag='EP', start=85, len=1),
#  Token(form='려면', tag='EC', start=86, len=2),
#  Token(form='여기', tag='NP', start=89, len=2),
#  Token(form='가세여', tag='NNP', start=92, len=3)]

# %% [markdown]
# ---
# # 형태소 분석 결과 - normalize옵션 선택시 받침 때문에 분석이 깨지는 것 방지
# ---

# %%
kiwi.tokenize("ㅋㅋㅋ 이런 것도 분석이 될까욬ㅋㅋ?", normalize_coda=True)
# Out:
# [Token(form='ㅋㅋㅋ', tag='SW', start=0, len=3),
#  Token(form='이런', tag='MM', start=4, len=2),
#  Token(form='것', tag='NNB', start=7, len=1),
#  Token(form='도', tag='JX', start=8, len=1),
#  Token(form='분석', tag='NNG', start=10, len=2),
#  Token(form='이', tag='JKC', start=12, len=1),
#  Token(form='되', tag='VV', start=14, len=1),
#  Token(form='ᆯ까요', tag='EF', start=14, len=3),
#  Token(form='ㅋㅋㅋ', tag='SW', start=16, len=3),
#  Token(form='?', tag='SF', start=19, len=1)]

# %% [markdown]
# ---
# ### 불용어 방지
# ---

# %%
from kiwipiepy.utils import Stopwords
stopwords = Stopwords()
kiwi.tokenize("카운더 보시는 할아버지만 불친절하지 음식은 맛있는 편이고 점심에 사람들 바글바글해서 대기시간이 좀 긴 편.", stopwords=stopwords)
# Out:
# [Token(form='카운더', tag='NNP', start=0, len=3),
#  Token(form='시', tag='EP', start=5, len=1),
#  Token(form='할아버지', tag='NNG', start=8, len=4),
#  Token(form='불', tag='XPN', start=14, len=1),
#  Token(form='친절', tag='NNG', start=15, len=2),
#  Token(form='지', tag='EF', start=18, len=1),
#  Token(form='음식', tag='NNG', start=20, len=2),
#  Token(form='맛있', tag='VA', start=24, len=2),
#  Token(form='편', tag='NNB', start=28, len=1),
#  Token(form='점심', tag='NNG', start=32, len=2),
#  Token(form='바글바글', tag='MAG', start=40, len=4),
#  Token(form='대기', tag='NNG', start=47, len=2),
#  Token(form='시간', tag='NNG', start=49, len=2),
#  Token(form='좀', tag='MAG', start=53, len=1),
#  Token(form='길', tag='VA', start=55, len=1),
#  Token(form='편', tag='NNB', start=57, len=1)]

# %%
# add, remove 메소드를 이용해 불용어 목록에 단어를 추가하거나 삭제할 수도 있습니다.
# stopwords.add(('결과', 'NNG'))
# kiwi.tokenize("분석 결과에서 불용어만 제외하고 출력할 수도 있다.", stopwords=stopwords)

# %% [markdown]
# ---
# ###  토큰의 정보
# ---

# %%
tokens = kiwi.tokenize("각 토큰은 여러 정보를 담고 있습니다.")
tokens[0]
# Out:
# Token(form='각', tag='MM', start=0, len=1)

# %%
print(tokens[0].form, '\n') # 형태소의 형태 정보

print(tokens[0].tag, '\n') # 형태소의 품사 정보

print(tokens[0].start, '\n') # 형태소의 문자 단위 시작점

print(tokens[0].end, '\n') # 형태소의 문자 단위 끝점

print(tokens[0].word_position, '\n') # 현 문장에서의 어절 번호

print(tokens[0].sent_position, '\n') # 형태소가 속한 문장 번호

print(tokens[0].line_number) # 형태소가 속한 줄의 번호
# Out:
# 각
#
# MM
#
# 0
#
# 1
#
# 0
#
# 0
#
# 0

# %% [markdown]
# ---
# ### 문장 분리
# ---

# %%
kiwi.split_into_sents("도가니탕 17000원 비싼데 가성비 너무 안좋네요.  포장하면 양이 엄청 적어요. 매장에서 먹었을때랑 심하게 차이나요. 파는 씻지도 않은거 흙 묻어있고 참..")
# Out:
# [Sentence(text='도가니탕 17000원 비싼데', start=0, end=15, tokens=None),
#  Sentence(text='가성비 너무 안좋네요.', start=16, end=28, tokens=None),
#  Sentence(text='포장하면 양이 엄청 적어요.', start=30, end=45, tokens=None),
#  Sentence(text='매장에서 먹었을때랑 심하게 차이나요.', start=46, end=66, tokens=None),
#  Sentence(text='파는 씻지도 않은거 흙 묻어있고 참..', start=67, end=88, tokens=None)]

# %%
kiwi.split_into_sents('친절하구 맛잇어요 파김치 별미... 헿')
# Out:
# [Sentence(text='친절하구 맛잇어요', start=0, end=9, tokens=None),
#  Sentence(text='파김치 별미...', start=10, end=19, tokens=None),
#  Sentence(text='헿', start=20, end=21, tokens=None)]

# %%
kiwi.split_into_sents("맛은 문제가 없지만 가성비가 너무 나쁘다. 10,000원 짜리 돈수백을 시키면 다른 집 5 ~ 6천원 보쌈정식보다 별로인 상이 나온다. 고기 양도 적고 마늘, 양파, 쌈장, 야채는 전혀 없다. 재방문의사는 물론 없다.")
# Out:
# [Sentence(text='맛은 문제가 없지만 가성비가 너무 나쁘다.', start=0, end=23, tokens=None),
#  Sentence(text='10,000원 짜리 돈수백을 시키면 다른 집 5 ~ 6천원 보쌈정식보다 별로인 상이 나온다.', start=24, end=75, tokens=None),
#  Sentence(text='고기 양도 적고 마늘, 양파, 쌈장, 야채는 전혀 없다.', start=76, end=107, tokens=None),
#  Sentence(text='재방문의사는 물론 없다.', start=108, end=121, tokens=None)]

# %%
# 사전에 새로운 단어를 추가할 수 있습니다.
# >>> kiwi.add_user_word("김갑갑", "NNP")
# True
# >>> kiwi.tokenize("김갑갑이 누구야")
# [Token(form='김갑갑', tag='NNP', start=0, len=3),
#  Token(form='이', tag='JKS', start=3, len=1),
#  Token(form='누구', tag='NP', start=5, len=2),
#  Token(form='야', tag='JKV', start=7, len=1)]

# %% [markdown]
# ---
# ### 오타 교정 (사소한 오타만 가능
# ---

# %%
kiwi = Kiwi(model_type='sbg', typos='basic')
kiwi.tokenize('외않됀대?')
# Out:
# [Token(form='왜', tag='MAG', start=0, len=1),
#  Token(form='안', tag='MAG', start=1, len=1),
#  Token(form='되', tag='VV', start=2, len=1),
#  Token(form='ᆫ대', tag='EF', start=2, len=2),
#  Token(form='?', tag='SF', start=4, len=1)]
